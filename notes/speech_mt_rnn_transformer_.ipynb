# %% [markdown]
# # Speech NLP: Paper Summary Serieis
#
# Too many texts already
#
# ---
#
# ### A COMPARATIVE STUDY ON TRANSFORMER VS RNN IN SPEECH APPLICATIONS
#
# This is perhaps one of the excellent papers I have read of speech focused NLP tasks. For others please see specific sections from the repo [automatic dubbing and its AI complete problems]().
#
#
# First thing is first, lets break down the title of the paper i) for first time readers, and ii) for structuring the summary. Remember the paper by itself is 6 pages, and I highly encourage you to read it before or after this summary, I am putting down summaries while reading papers to help me organize the flow of information about different topics - then for posting it like this I only add some descriptive information and decoration to help all reader types.
#
#
#
# #### __Comparative Studies of NN approaches for NLP Tasks__
#
# In the past few years there are several works that have been published as a review of a specific topic or as a comparison, for instance comparing recurrent neural networks (RNN), against Transformer NN's (TNN). Most comparisons can be categorized in two, i) takes different architectures, ii) ..
#
#
# #### __What are RNN and TNN__
#
# If you would like to see introductory concepts on NNs from their inception in the 19XX, their relation to how our mind works (at least to our understanding), and the different types (Perceptrons, MLP, FNN, etc), checkout my introductory note [here](defn, summary, formalization, sample code - from msc, thesis and other readings)
#
#
# Although section 2 and 3 of the paper (perhaps) does one of the best formalization of seq2seq architectures using RNN and TNN, in this section I will go summarizing RNN and TNN in a comparative manner. (From my paper, other works: approach:- definition, formalization, code, sample task)
#
#
#
# #### Speech Tasks in NLP
#
# What are the prominent speech tasks in NLP? If you are new to NLP, no worries perhaps you area already interacting with several NLP applications in your daily life. For example think about Alexa, Siri, Hey Google - right those has alot of speech NLP tasks.
#
# Ok, what are these speech tasks:
#
#
#
#
# Automatic Speech Recognition (ASR):
#
# -
#
# Speech to Text Translation (STT):
#
# - This is an addition evolution of the ASR task, where the target output is now in a different language. Traditionally a speech from a source language ($S$) is translated to a target ($T$), first using an ASR then an MT model. Recntly however things are changing rapidly with an end-to-end approach.
#
#
# Text to Speech Generation (TTS):
#
# -
#
#
# Speech to Speech Translation (SST):
#
# -
#
#
# Note: if this tasks interest you? perhaps you can also find my note regarding Automatic Machine Dubbing (AMD) where ... and an AI complete problem [here]().
#
#
#
# ### The Paper (Karita et al. 2019)
#
# TLDR; Recently TNN's have achieved sota performance on MT and many other NLP tasks, their work investigates and compares RNN and TNN performance on speech based NLP tasks that are defined above. Although there are cases where RNN wins (such as ...), TNN is found to be the clear winner in the majority of tasks and benchmarks.
#
#
#
# #### RNN for Speech Tasks
#
# Karita et al., provides a unified presentation of the of what an RNN in speech tasks look like (see figure).
#
#
# HERE: FIRST READ SECTION ON PAPER, SUMMARIZE IT IN OWN WORDS
#
#
#
#
#
# #### TNN for Speech Tasks
#
#
#
#
#
# ### This work contributes
#
# The introduction part goes here
#
# - TNN are hard to apply to speech since it requires complex model tunings. Rekits et al., work and other new work I think this is not an issue anymore. However, there are still works that remain - Apple paper perhaps is a good read on this.
#
#
# - Open source toolkits for speech NLP applications, this paper provides (list others - facebook, fbk, etc, us?)
#
#
# - measures on word/char/regression errors
#
# - ESPnet
#
#
# ### Others works that are inline
#
# - FB's new toolkit
#
# - ?
