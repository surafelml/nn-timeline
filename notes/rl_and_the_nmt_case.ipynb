# %% [markdown]
# # Layout of this Note
#
# - goes here
#
#
#
# ## Concepts/Notions
#
# -  optimize non-differentiable score functions
#
# - tackling the “exposure bias”
#
# - Various policy gradient methods
#
# - RL is for training GANs
#
#
#
# ## Contribution and Core Findings
#
# - peakiness effect (PKE)
#
# - practices in MT which should be avoided
#
#
#
# # RL in MT (Introduction and Policies)
#
#
# - ...
#
# - For each generated token from the MT (y_i), assume there is a score r
#
# - - r is a nll, MT metric (BLEU, ..., LR_s/t, laser, etc)
#
#
# - NB: "...assume there is exactly one valid target token, as de facto, training is done against a single reference (Schulz et al., 2018)."
#
# - - in our case this is disbuited.
#
#
# - Approximatin token-level reward
#
# - - Monte carlo
# - - sentence-level reward (at end of decoding / episode)
#
#
# ## Goal of RL:
#
# - maximize the expected reward (-ve loss) for the episode (R), or minimize the risk
#
# - estimation methods,
#
# Reinforce:
#
# - when is it introduced ?
#
# - how does it work?
#
# - also assume there is exactly one valid target token, as de facto, training is done against a single reference (Schulz et al., 2018).
#
# - uscases includes n MT, text generation, and image-to-text task (see ref), and
#
#
# -  2015). Lately, an especially prominent use for REINFORCE is
#
#
# CMRT:
#
# - when is it introduced
#
# - how does it work
#
#
# - variations
#
# - despite its name, CMRT does not optimize R, nor does it optimize
# E[]

# %%
# Sample code for optimizing with Reinforce ed MRT
